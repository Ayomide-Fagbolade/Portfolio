# %%
# Install required libraries
# !pip install scholarly pandas
# Out:
# Requirement already satisfied: scholarly in /usr/local/lib/python3.11/dist-packages (1.7.11)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: arrow in /usr/local/lib/python3.11/dist-packages (from scholarly) (1.3.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from scholarly) (4.13.3)
# Requirement already satisfied: bibtexparser in /usr/local/lib/python3.11/dist-packages (from scholarly) (1.4.3)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.11/dist-packages (from scholarly) (1.2.18)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.11/dist-packages (from scholarly) (2.0.3)
# Requirement already satisfied: free-proxy in /usr/local/lib/python3.11/dist-packages (from scholarly) (1.1.3)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from scholarly) (0.28.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from scholarly) (1.0.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from scholarly) (2.32.3)
# Requirement already satisfied: selenium in /usr/local/lib/python3.11/dist-packages (from scholarly) (4.29.0)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.11/dist-packages (from scholarly) (3.0.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from scholarly) (4.12.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.11/dist-packages (from arrow->scholarly) (2.9.0.20241206)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->scholarly) (2.6)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from bibtexparser->scholarly) (3.2.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated->scholarly) (1.17.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from free-proxy->scholarly) (5.3.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->scholarly) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx->scholarly) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->scholarly) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx->scholarly) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->scholarly) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->scholarly) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->scholarly) (2.3.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->scholarly) (1.7.1)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.11/dist-packages (from selenium->scholarly) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.11/dist-packages (from selenium->scholarly) (0.12.2)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/lib/python3.11/dist-packages (from selenium->scholarly) (1.8.0)
# Requirement already satisfied: sphinx<9,>=6 in /usr/local/lib/python3.11/dist-packages (from sphinx-rtd-theme->scholarly) (8.1.3)
# Requirement already satisfied: docutils<0.22,>0.18 in /usr/local/lib/python3.11/dist-packages (from sphinx-rtd-theme->scholarly) (0.21.2)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /usr/local/lib/python3.11/dist-packages (from sphinx-rtd-theme->scholarly) (4.1)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly) (2.18.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly) (1.4.1)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly) (24.2)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium->scholarly) (25.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium->scholarly) (2.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium->scholarly) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium->scholarly) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.11/dist-packages (from trio-websocket~=0.9->selenium->scholarly) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1->sphinx<9,>=6->sphinx-rtd-theme->scholarly) (3.0.2)

# %%
from scholarly import scholarly
import pandas as pd

# %%
from scholarly import scholarly

class ScholarScraper:
    def __init__(self, institution, author_names, emails=None):
        self.institution = institution
        self.author_names = author_names
        self.emails = emails if emails else []
        self.scholar_ids_dict = {}

    def get_scholar_ids_by_institution_and_email(self):
        """
        Fetch Google Scholar IDs for authors from a specified institution or email.

        Returns:
            dict: A dictionary with author names as keys and Scholar IDs as values.
        """
        for name in self.author_names:
            print(f"Searching for: {name}")

            # Search for the author by name
            search_query = scholarly.search_author(name)

            # Iterate through search results
            for author in search_query:

                # Check if the institution or email matches
                if (self.institution.lower() in author['affiliation'].lower() or
                    any(email.lower() in author.get('email', '').lower() for email in self.emails)):
                    print(f"Match found: {author['name']} at {author['affiliation']}")
                    if author.get('email', '').lower():
                        print(f"Email match found: {author['email']}")

                    self.scholar_ids_dict[name] = author['scholar_id']
                    break  # Found the right author, stop looking further
            else:
                # If no match is found

                print(f"No match found for {name} at {self.institution} or with the provided emails")
                self.scholar_ids_dict[name] = None  # Use None to indicate no Scholar ID found
                self.scholar_ids_dict[name] = author['scholar_id']

        return self.scholar_ids_dict

    def get_recent_publications(self, scholar_ids_dict):
        """
        Fetch all publications for each author between 2022 and 2024 using `scholarly`.

        Returns:
            dict: A dictionary where each key is an author's name, and the value is a list of publications
                  between 2022 and 2024 (each as a dict with 'title' and 'year').
        """
        results = {}

        for name, scholar_id in scholar_ids_dict.items():
            if scholar_id is None:
                results[name] = "No Scholar ID available"
                continue

            print(f"Fetching publications for {name} (Scholar ID: {scholar_id})")
            try:
                # Retrieve the author's profile and publications using `scholarly`
                author = scholarly.search_author_id(scholar_id)
                author = scholarly.fill(author)  # This fetches more detailed data about the author

                # Filter publications between 2022 and 2024
                publications = []
                for pub in author['publications']:
                    year = pub['bib'].get('pub_year')
                    if year and year.isdigit():
                        year = int(year)
                        if 2022 <= year <= 2024:  # Filter based on the year range
                            title = pub['bib']['title']
                            publications.append({'title': title, 'year': year})

                results[name] = publications if publications else "No publications found in the specified range"

            except Exception as e:
                print(f"Error fetching data for {name}: {e}")
                results[name] = "Error fetching data"

        return results

    def scrape(self):
        """
        Combines the functionality of fetching Scholar IDs and publications into one process.

        Returns:
            dict: A dictionary containing the Google Scholar IDs and publications between 2022 and 2024 for each author.
        """
        # First, get the Scholar IDs by institution and email
        scholar_ids = self.get_scholar_ids_by_institution_and_email()

        # Then, get the publications for each author between 2022 and 2024
        recent_publications = self.get_recent_publications(scholar_ids)

        # Combine results
        combined_results = {
            'scholar_ids': scholar_ids,
            'recent_publications': recent_publications
        }

        return combined_results

    def display_results(self, results):
        """
        Display the results in a user-friendly format.

        Args:
            results (dict): The dictionary containing Scholar IDs and recent publications.
        """
        print("\nScholar IDs:")
        for name, scholar_id in results['scholar_ids'].items():
            print(f"{name}: {scholar_id}")

        print("\nRecent Publications (2022-2024):")
        for name, pubs in results['recent_publications'].items():
            print(f"\n{name}'s Publications:")
            if isinstance(pubs, str):
                print(pubs)
            else:
                for pub in pubs:
                    print(f"  Title: {pub['title']}, Year: {pub['year']}")

# %%
# Example usage:
institution_name = "University of Illinois at Urbana Champaign"
author_names =faculty_names_illinois = [
    "Imad Al-Qadi",
    "Bassem O. Andrawes",
    "Christopher P. L. Barkan",
    "Ana P. Barros",
    "Rahim F. Benekohal",
    "Ximing Cai",
    "Eun Jeong Cha",
    "R. D. Cusick",
    "C. Armando Duarte",
    "J. Riley Edwards",
    "Ahmed Elbanna",
    "Nora El-Gohary",
    "Khaled A. El-Rayes",
    "Rosa M. Espinosa Marzal",
    "Larry A. Fahnestock",
    "Marcelo H. Garcia",
    "Paolo Gardoni",
    "Nishant Garg",
    "Mani Golparvar-Fard",
    "Jeremy Guest",
    "Ramez M. Hajj",
    "Youssef M. A. Hashash",
    "Hannah M. Horowitz",
    "Houtan Jebelli",
    "Nick Jones",
    "Megan Konar",
    "Eleftheria Kontou",
    "Praveen Kumar",
    "James M. LaFave",
    "Lewis J. Lehe",
    "Franklin T. Lombardo",
    "Oscar Lopez-Pamies",
    "Roman Makhnenko",
    "Arif Masud",
    "Megan L. Matthews",
    "Ran Mei",
    "Hadi Meidani",
    "Gholamreza Mesri",
    "Helen Nguyen",
    "Scott M. Olson",
    "Yanfeng Ouyang",
    "John S. Popovics",
    "Jeffery R. Roesler",
    "Murugesu Sivapalan",
    "B. F. Spencer, Jr",
    "Timothy D. Stark",
    "Ashlynn Stillwell",
    "Ann Sychterz",
    "Alireza Talebpour",
    "Alexandre Tartakovsky",
    "Christopher Tessum",
    "Rafael O. Tinoco",
    "Erol Tutumluer",
    "Vishal Verma",
    "Na Wei",
    "Jinhui Yan",
    "X. Shelly Zhang",
    "Lei Zhao"
]





emails = "illinois.edu"  # List of emails to check

# Create an instance of the ScholarScraper class
scraper = ScholarScraper(institution_name, author_names, emails)

# Scrape both Scholar IDs and recent publications
results = scraper.scrape()

# Display the results using the display_results method
scraper.display_results(results)
# Out:
# Searching for: Imad Al-Qadi
# No match found for Imad Al-Qadi at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Bassem O. Andrawes
# No match found for Bassem O. Andrawes at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Christopher P. L. Barkan
# No match found for Christopher P. L. Barkan at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Ana P. Barros
# No match found for Ana P. Barros at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Rahim F. Benekohal
# No match found for Rahim F. Benekohal at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Ximing Cai
# No match found for Ximing Cai at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Eun Jeong Cha
# No match found for Eun Jeong Cha at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: R. D. Cusick
# No match found for R. D. Cusick at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: C. Armando Duarte
# No match found for C. Armando Duarte at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: J. Riley Edwards
# No match found for J. Riley Edwards at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Ahmed Elbanna
# No match found for Ahmed Elbanna at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Nora El-Gohary
# No match found for Nora El-Gohary at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Khaled A. El-Rayes
# No match found for Khaled A. El-Rayes at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Rosa M. Espinosa Marzal
# No match found for Rosa M. Espinosa Marzal at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Larry A. Fahnestock
# No match found for Larry A. Fahnestock at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Marcelo H. Garcia
# No match found for Marcelo H. Garcia at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Paolo Gardoni
# No match found for Paolo Gardoni at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Nishant Garg
# No match found for Nishant Garg at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Mani Golparvar-Fard
# No match found for Mani Golparvar-Fard at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Jeremy Guest
# No match found for Jeremy Guest at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Ramez M. Hajj
# No match found for Ramez M. Hajj at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Youssef M. A. Hashash
# No match found for Youssef M. A. Hashash at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Hannah M. Horowitz
# No match found for Hannah M. Horowitz at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Houtan Jebelli
# No match found for Houtan Jebelli at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Nick Jones
# No match found for Nick Jones at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Megan Konar
# No match found for Megan Konar at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Eleftheria Kontou
# No match found for Eleftheria Kontou at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Praveen Kumar
# No match found for Praveen Kumar at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: James M. LaFave
# No match found for James M. LaFave at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Lewis J. Lehe
# No match found for Lewis J. Lehe at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Franklin T. Lombardo
# No match found for Franklin T. Lombardo at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Oscar Lopez-Pamies
# No match found for Oscar Lopez-Pamies at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Roman Makhnenko
# No match found for Roman Makhnenko at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Arif Masud
# No match found for Arif Masud at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Megan L. Matthews
# No match found for Megan L. Matthews at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Ran Mei
# No match found for Ran Mei at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Hadi Meidani
# No match found for Hadi Meidani at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Gholamreza Mesri
# No match found for Gholamreza Mesri at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Helen Nguyen
# No match found for Helen Nguyen at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Scott M. Olson
# No match found for Scott M. Olson at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Yanfeng Ouyang
# No match found for Yanfeng Ouyang at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: John S. Popovics
# No match found for John S. Popovics at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Jeffery R. Roesler
# No match found for Jeffery R. Roesler at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Murugesu Sivapalan
# No match found for Murugesu Sivapalan at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: B. F. Spencer, Jr
# No match found for B. F. Spencer, Jr at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Timothy D. Stark
# No match found for Timothy D. Stark at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Ashlynn Stillwell
# No match found for Ashlynn Stillwell at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Ann Sychterz
# No match found for Ann Sychterz at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Alireza Talebpour
# No match found for Alireza Talebpour at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Alexandre Tartakovsky
# No match found for Alexandre Tartakovsky at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Christopher Tessum
# No match found for Christopher Tessum at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Rafael O. Tinoco
# No match found for Rafael O. Tinoco at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Erol Tutumluer
# No match found for Erol Tutumluer at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Vishal Verma
# No match found for Vishal Verma at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Na Wei
# No match found for Na Wei at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: Jinhui Yan
# No match found for Jinhui Yan at University of Illinois at Urbana Champaign or with the provided emails
# Searching for: X. Shelly Zhang
# Match found: Xiaojia Shelly Zhang at University of Illinois at Urbana Champaign
# Searching for: Lei Zhao
# No match found for Lei Zhao at University of Illinois at Urbana Champaign or with the provided emails
# Fetching publications for Imad Al-Qadi (Scholar ID: XcWBRgEAAAAJ)
# Fetching publications for Bassem O. Andrawes (Scholar ID: XcWBRgEAAAAJ)
